# %%
print(464)
# Out:
# 464

# %% [markdown]
# VARIABLES

# %%
number = 123
strings = "123"
number = type(number)
strings = type(strings)

# %%
strings
## REASON THAT USING NUMBER AS STRING WOULD RESUL IN ERROR WHEN USED * SIGN EXAMPLE GIVEN BELOW
# Out:
# str

# %%
number
# Out:
# int

# %%
a = '2'
b = '3'
c = a*b # this is the error which is given in previous cell
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 a = '2'
#       2 b = '3'
# ----> 3 c = a*b # this is the error which is given in previous cell
#       4 c
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
player1 = 'Ronaldo'
player2 = 'Messi'

print(player1,player2)
# Out:
# Ronaldo Messi

# %%
#OPERATORS
num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
print("First Number ",num1 )
print("Second Number ",num2 )
answer = num1 + num2
print(answer)
# Out:
# First Number  10
# Second Number  5
# 15

# %%
# fnumber
print("First Number num1")
print(f"First Number {num1}")
# Out:
# First Number num1
# First Number 10
